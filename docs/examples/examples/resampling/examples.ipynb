# %% [markdown]
# ## Tutorials

# %% [markdown]
# ### Introduction

# %% [markdown]
# * [Introduction](introduction/01-introduction.ipynb)
# * [API levels](introduction/02-api-layers.ipynb)
# * [Data formats](introduction/03-formats.ipynb)
# * [Styles](introduction/04-styles.ipynb)
# * [Metadata formatting](introduction/05-metadata-formatting.ipynb)
# * [Domains and projections](introduction/06-domains.ipynb)

# %% [markdown]
# ### Source types

# %% [markdown]
# * [Plotting numpy arrays](source-types/source-numpy.ipynb)
# * [Plotting netCDF data](source-types/source-netcdf.ipynb)
# * [Plotting GRIB data](source-types/source-grib.ipynb)
# * [Plotting xarray data](source-types/source-xarray.ipynb)

# %% [markdown]
# ### Grid types

# %% [markdown]
# * [Regular lat-lon](grid-types/grid-types-regular-ll.ipynb)
# * [Reduced Gaussian](grid-types/grid-types-reduced-gg.ipynb)
# * [HEALPix](grid-types/grid-types-healpix.ipynb)

# %% [markdown]
# ### Vector data (`quiver`, `barbs` and `streamplot`)

# %% [markdown]
# * [Wind barbs](vectors/vectors-basic-barbs.ipynb)
# * [Quiver (wind arrows)](vectors/vectors-basic-quiver.ipynb)
# * [Streamplots](vectors/vectors-streamplot.ipynb)
# * [Vector subsampling](vectors/vectors-subsampling.ipynb)
# * [Vector interpolation](vectors/vectors-regridding.ipynb)
# * [Vector styles](vectors/vectors-styles.ipynb)

# %% [markdown]
# ### Contour lines (`contour`)

# %% [markdown]
# * [Introduction to contour lines](contour/contour-introduction.ipynb)
# * [Contour line styles](contour/contour-linestyles.ipynb)
# * [Reusable contour styles](contour/contour-styles.ipynb)

# %% [markdown]
# ### Filled contours (`contourf`)

# %% [markdown]
# * [Introduction to filled contours](contourf/contourf-introduction.ipynb)
# * [Filled contour styles](contourf/contourf-styles.ipynb)
# * [Combining filled contours and contour lines](contourf/contourf-contour-overlay.ipynb)

# %% [markdown]
# ### Points and cells (`point_cloud`, `grid_points`, `grid_cells`, `scatter`)

# %% [markdown]
# * [Point cloud](points-and-cells/point-cloud.ipynb)
# * [Grid points](points-and-cells/grid-points.ipynb)
# * [Grid cells](points-and-cells/grid-cells.ipynb)
# * [Scatter](points-and-cells/scatter.ipynb)

# %% [markdown]
# ### Miscellaneous plotting methods

# %% [markdown]
# * [Choropleth maps](misc/choropleth.ipynb)
# * [RGB composite images](misc/rgb-composite.ipynb)

# %% [markdown]
# ### Time series

# %% [markdown]
# * [Introduction to time series plots](time-series/timeseries-introduction.ipynb)
# * [Climate stripe plots](time-series/timeseries-climate-stripes.ipynb)
# * [Global average temperature chart](time-series/timeseries-global-temperature.ipynb)

# %% [markdown]
# ### Resampling

# %% [markdown]
# * [Regridding (HEALPix / reduced Gaussian)](resampling/regridding.ipynb)
# * [Bilinear interpolation](resampling/resampling-bilinear.ipynb)
# * [Nearest-neighbour resampling](resampling/resampling-nearest-neighbour.ipynb)
# * [Regrid](resampling/resampling-regrid.ipynb)
# * [Subsampling](resampling/resampling-subsample.ipynb)
