# %%
import earthkit.data
import earthkit.plots

# %%
data = earthkit.data.from_source(
    "url",
    "https://get.ecmwf.int/repository/test-data/earthkit-regrid/test-data/global_0_360/O32.grib",
)

data.ls()
# Out:
# O32.grib:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
#   centre shortName typeOfLevel  level  dataDate  dataTime stepRange dataType  \
# 0   ecmf        2t     surface      0  20231010      1200         0       an
#
#    number    gridType
# 0       0  reduced_gg

# %%
chart = earthkit.plots.Map(domain="Arctic")

chart.contourf(data, units="celsius")

chart.title()
chart.legend()

chart.coastlines()
chart.gridlines()

chart.show()
# Out:
# LL-1x1-90:0:-90:359-c3c76e2a27e53dbd0fdd17b7eb075fea-011801.npz:   0%|          | 0.00/821k [00:00<?, ?B/s]
