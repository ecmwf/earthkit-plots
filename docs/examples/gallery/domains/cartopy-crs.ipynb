# %% [markdown]
# ## Coordinate systems

# %%
import earthkit.plots
import cartopy.crs as ccrs

my_map = earthkit.plots.Map(crs=ccrs.Robinson())

my_map.land()
my_map.borders()
my_map.coastlines()
my_map.gridlines()

my_map.title("{crs}")

my_map.show()
