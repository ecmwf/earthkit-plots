# %%
import earthkit.plots

# %%
subplot = earthkit.plots.Subplot()
subplot.line([1, 3, 2, 5, 4, 7])

subplot.show()

# %%
subplot = earthkit.plots.Subplot()
subplot.bar([1, 3, 2, 5, 4, 7], zorder=100)

subplot.show()
